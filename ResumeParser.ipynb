# %%
import nltk
import re
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

nltk.download('punkt')
nltk.download('stopwords')

# Initialize candidate data
candidates = []

class Candidate:
    def __init__(self):
        self.data = {
            "name": "",
            "skills": [],
            "experience": "",
            "certifications": [],
            "languages": [],
            "projects": [],
            "awards": [],
        }
        self.score = 0

# Input from user for different components of the resume
def input_component(component_name):
    return input(f"Enter {component_name}: ")

# Create candidates based on user input
num_candidates = int(input("Enter the number of candidates: "))
for _ in range(num_candidates):
    candidate = Candidate()
    candidate.data["name"] = input_component("Name")
    candidate.data["skills"] = input_component("Skills").split(',')
    candidate.data["experience"] = input_component("Experience")
    candidate.data["certifications"] = input_component("Certifications").split(',')
    candidate.data["languages"] = input_component("Languages").split(',')
    candidate.data["projects"] = input_component("Projects").split(',')
    candidate.data["awards"] = input_component("Awards").split(',')
    candidates.append(candidate)

# Compare candidates and calculate scores
for candidate in candidates:
    # Compare logic - Modify this based on your criteria
    # For demonstration, I'm checking if the candidate has Python skills and relevant job title
   
    for skill in candidate.data["skills"]:
        candidate.score += 1
    candidate.score = candidate.score + int(candidate.data["experience"])
    for certificate in candidate.data["certifications"]:
        candidate.score += 1
    for language in candidate.data["languages"]:
        candidate.score += 1
    for project in candidate.data["projects"]:
        candidate.score += 1
    for award in candidate.data["awards"]:
        candidate.score += 1
    
    

# Find the candidate with the highest score
best_candidate = max(candidates, key=lambda candidate: candidate.score, default=None)

# Print the name of the correct candidate or "None"
if best_candidate and best_candidate.score > 0:
    print("Correct Candidate:")
    print(best_candidate.data["name"])
    print(best_candidate.data["skills"])
    print(best_candidate.data["experience"])
    print(best_candidate.data["certifications"])
    print(best_candidate.data["languages"])
    print(best_candidate.data["projects"])
    print(best_candidate.data["awards"])
else:
    print("None")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Enter the number of candidates: 3
# Enter Name: john
# Enter Skills: python,data analysis,problem solving
# Enter Experience: 7
# Enter Certifications: python,DSA with python
# Enter Languages: english,hindi
# Enter Projects: calculator,temprature convertor
# Enter Awards:
# Enter Name: emily
# Enter Skills: java,c++
# Enter Experience: 5
# Enter Certifications: java
# Enter Languages: english
# Enter Projects: tictactoe
# Enter Awards:
# Enter Name: alok
# Enter Skills: php,css,html
# Enter Experience: 2
# Enter Certifications: web development
# Enter Languages: english,hindi
# Enter Projects: digital clock website
# Enter Awards:
# Correct Candidate:
# john
# ...
